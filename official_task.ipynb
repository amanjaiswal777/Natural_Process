# %%
import sys
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.pdfpage import PDFPage
from pdfminer.converter import XMLConverter, HTMLConverter, TextConverter
from pdfminer.layout import LAParams
import io

def pdfparser(data):

    fp = open(data, 'rb')
    rsrcmgr = PDFResourceManager()
    retstr = io.StringIO()
    codec = 'utf-8'
    laparams = LAParams()
    device = TextConverter(rsrcmgr, retstr, codec=codec, laparams=laparams)
    # Create a PDF interpreter object.
    interpreter = PDFPageInterpreter(rsrcmgr, device)
    # Process each page contained in the document.

    for page in PDFPage.get_pages(fp):
        interpreter.process_page(page)
        data =  retstr.getvalue()

    return data

if __name__ == '__main__':
    file_path = "Amit.pdf"
    data = pdfparser(file_path)

# %% [markdown]
# Contact
#
# www.linkedin.com/in/ssamitkmr
# (LinkedIn)
#
# Top Skills
# Algorithms
# Java
# Python
#
# Languages
# English (Professional Working)
# Hindi (Native or Bilingual)
#
# Honors-Awards
# Certificate of Merit
#
#
#
#
#
#
#
# Amit Kumar
#
# Actively Looking for Opportunites| Ex-Shuttl | Ex- Times Internet | IIT
# Kanpur
# Gurgaon, India
#
# Summary
# Software Developer with experience of building scalable tech
# products and solutions. Skilled in Python, Nodejs and Java. Strong
# engineering professional with a Bachelor’s Degree from IIT Kanpur.
#
# Experience
#
# Udyami Media Labs
# Co-Founder
# July 2019 - Present
# Noida Area, India
#
# Shuttl
# Software Engineer
# September 2018 - June 2019 (10 months)
# Gurgaon, India
# Worked in system-rewrite and software revamp of Shuttl from monolith
# architecture to microservice architecture.
#
# -  Developer Payments microservice with third-party integration such as Paytm,
# Mobikwik, Razorpay, etc. (Flask, Postgres, RabbitMQ, Docker)
# -  Developed GTFS microservice responsible for periodic data feed to Google
# Maps for Shuttl bus routes and time tables. (Flask, Postgres, Docker)
# - Developed Slackbot to deploy and migrate microservices on Staging and
# Production Environment
# (Ruby, Nomad, Docker, Slack API)
#
# Times Internet
# 2 years 2 months
# Full Stack Developer (BrainBaazi)
# December 2017 - August 2018 (9 months)
# Noida Area, India
#
# Page 1 of 3
#
#
#
#
#
#
#
# • Developed REST API for user registration, login, dashboard and leaderboard
# in Nodejs for brainbaazi app using MongoDB as database
# • Developed a Quiz control dashboard prototype in Python which later
# upgraded to actual Quiz control dashboard
# Developed Brainbaazi iOS App
# • Developed Brainbaazi iOS from scratch with features User Registration,
# Login, Profile management, Multilingual, Support and real time communication
# for live game shows
# • Responsible for REST API Integration, realtime socket communication with
# server and managing user state for the live games
#
# Software Engineer
# July 2016 - November 2017 (1 year 5 months)
# Gurgaon, India
# Working on iOS SDK Libraries for various applications of Times Internet
# 1. • Developed a SDK integration Platfarm ’TILSDK’ from scratch to bundle
# different SDKs, Currently being used by major apps like Gaana, TOI, ET etc.
# 2. Work Involved developing architecture, using suitable design patterns,
# following standard practices of SDK development and coordinating with
# different teams for easy integration of SDKs
#
# SoftTech Engineers Pvt. Ltd.
# Software Developer Internship
# May 2015 - July 2015 (3 months)
# Pune
# Worked on testing automation for company's products
# 1. Explored various testing automation tools
# 2. Wrote automation testing scripts for Microsoft UI Automation to test Opticon
# (One of company's product)
#
# Worked on visualisation analytical data in to charts, graph which further used
# to build a tool for business intelligence.
#
# Education
# Indian Institute of Technology, Kanpur
# Bachelor of Technology (B.Tech.), Computer Science · (2012 - 2016)
#
# Page 2 of 3
#
#
#
#
#
#
#
# Jawahar Navodaya Vidyalaya Bangalore Urban
# 11th and 12th, Science · (2010 - 2012)
#
# Jawahar Navodaya Vidyalaya Amroha
# High School, Science · (2005 - 2010)
#
# Page 3 of 3
#
#
#
#
#
# ['Contact', 'www.linkedin.com/in/ssamitkmr', '(', 'LinkedIn', ')', 'Top', 'Skills', 'Algorithms', 'Java', 'Python', 'Languages', 'English', '(', 'Professional', 'Working', ')', 'Hindi', '(', 'Native', 'or', 'Bilingual', ')', 'Honors-Awards', 'Certificate', 'of', 'Merit', 'Amit', 'Kumar', 'Actively', 'Looking', 'for', 'Opportunites|', 'Ex-Shuttl', '|', 'Ex-', 'Times', 'Internet', '|', 'IIT', 'Kanpur', 'Gurgaon', ',', 'India', 'Summary', 'Software', 'Developer', 'with', 'experience', 'of', 'building', 'scalable', 'tech', 'products', 'and', 'solutions', '.', 'Skilled', 'in', 'Python', ',', 'Nodejs', 'and', 'Java', '.', 'Strong', 'engineering', 'professional', 'with', 'a', 'Bachelor', '’', 's', 'Degree', 'from', 'IIT', 'Kanpur', '.', 'Experience', 'Udyami', 'Media', 'Labs', 'Co-Founder', 'July', '2019', '-', 'Present', 'Noida', 'Area', ',', 'India', 'Shuttl', 'Software', 'Engineer', 'September', '2018', '-', 'June', '2019', '(', '10', 'months', ')', 'Gurgaon', ',', 'India', 'Worked', 'in', 'system-rewrite', 'and', 'software', 'revamp', 'of', 'Shuttl', 'from', 'monolith', 'architecture', 'to', 'microservice', 'architecture', '.', '-', 'Developer', 'Payments', 'microservice', 'with', 'third-party', 'integration', 'such', 'as', 'Paytm', ',', 'Mobikwik', ',', 'Razorpay', ',', 'etc', '.', '(', 'Flask', ',', 'Postgres', ',', 'RabbitMQ', ',', 'Docker', ')', '-', 'Developed', 'GTFS', 'microservice', 'responsible', 'for', 'periodic', 'data', 'feed', 'to', 'Google', 'Maps', 'for', 'Shuttl', 'bus', 'routes', 'and', 'time', 'tables', '.', '(', 'Flask', ',', 'Postgres', ',', 'Docker', ')', '-', 'Developed', 'Slackbot', 'to', 'deploy', 'and', 'migrate', 'microservices', 'on', 'Staging', 'and', 'Production', 'Environment', '(', 'Ruby', ',', 'Nomad', ',', 'Docker', ',', 'Slack', 'API', ')', 'Times', 'Internet', '2', 'years', '2', 'months', 'Full', 'Stack', 'Developer', '(', 'BrainBaazi', ')', 'December', '2017', '-', 'August', '2018', '(', '9', 'months', ')', 'Noida', 'Area', ',', 'India', 'Page', '1', 'of', '3', '•', 'Developed', 'REST', 'API', 'for', 'user', 'registration', ',', 'login', ',', 'dashboard', 'and', 'leaderboard', 'in', 'Nodejs', 'for', 'brainbaazi', 'app', 'using', 'MongoDB', 'as', 'database', '•', 'Developed', 'a', 'Quiz', 'control', 'dashboard', 'prototype', 'in', 'Python', 'which', 'later', 'upgraded', 'to', 'actual', 'Quiz', 'control', 'dashboard', 'Developed', 'Brainbaazi', 'iOS', 'App', '•', 'Developed', 'Brainbaazi', 'iOS', 'from', 'scratch', 'with', 'features', 'User', 'Registration', ',', 'Login', ',', 'Profile', 'management', ',', 'Multilingual', ',', 'Support', 'and', 'real', 'time', 'communication', 'for', 'live', 'game', 'shows', '•', 'Responsible', 'for', 'REST', 'API', 'Integration', ',', 'realtime', 'socket', 'communication', 'with', 'server', 'and', 'managing', 'user', 'state', 'for', 'the', 'live', 'games', 'Software', 'Engineer', 'July', '2016', '-', 'November', '2017', '(', '1', 'year', '5', 'months', ')', 'Gurgaon', ',', 'India', 'Working', 'on', 'iOS', 'SDK', 'Libraries', 'for', 'various', 'applications', 'of', 'Times', 'Internet', '1', '.', '•', 'Developed', 'a', 'SDK', 'integration', 'Platfarm', '’', 'TILSDK', '’', 'from', 'scratch', 'to', 'bundle', 'different', 'SDKs', ',', 'Currently', 'being', 'used', 'by', 'major', 'apps', 'like', 'Gaana', ',', 'TOI', ',', 'ET', 'etc', '.', '2', '.', 'Work', 'Involved', 'developing', 'architecture', ',', 'using', 'suitable', 'design', 'patterns', ',', 'following', 'standard', 'practices', 'of', 'SDK', 'development', 'and', 'coordinating', 'with', 'different', 'teams', 'for', 'easy', 'integration', 'of', 'SDKs', 'SoftTech', 'Engineers', 'Pvt', '.', 'Ltd.', 'Software', 'Developer', 'Internship', 'May', '2015', '-', 'July', '2015', '(', '3', 'months', ')', 'Pune', 'Worked', 'on', 'testing', 'automation', 'for', 'company', "'s", 'products', '1', '.', 'Explored', 'various', 'testing', 'automation', 'tools', '2', '.', 'Wrote', 'automation', 'testing', 'scripts', 'for', 'Microsoft', 'UI', 'Automation', 'to', 'test', 'Opticon', '(', 'One', 'of', 'company', "'s", 'product', ')', 'Worked', 'on', 'visualisation', 'analytical', 'data', 'in', 'to', 'charts', ',', 'graph', 'which', 'further', 'used', 'to', 'build', 'a', 'tool', 'for', 'business', 'intelligence', '.', 'Education', 'Indian', 'Institute', 'of', 'Technology', ',', 'Kanpur', 'Bachelor', 'of', 'Technology', '(', 'B.Tech', '.', ')', ',', 'Computer', 'Science', '·', '(', '2012', '-', '2016', ')', 'Page', '2', 'of', '3', 'Jawahar', 'Navodaya', 'Vidyalaya', 'Bangalore', 'Urban', '11th', 'and', '12th', ',', 'Science', '·', '(', '2010', '-', '2012', ')', 'Jawahar', 'Navodaya', 'Vidyalaya', 'Amroha', 'High', 'School', ',', 'Science', '·', '(', '2005', '-', '2010', ')', 'Page', '3', 'of', '3']

# %% [markdown]
# Deepti Mullur
#
# SOFTWARE ENGINEER · JAVA BACK END DEVELOPER · TOTAL EXPERIENCE : 4 YEARS
#
# Bengaluru, India
#
# (+91)9035113717
#
# |
#
# deepti.mullur@gmail.com
#
# Data Structures, Design Patterns, Algorithms
#
#
# Skills
#
# Programming  JAVA, Groovy, Node.JS, JSON, XML
#
# Technologies  SQL, Web Services, Maven
#
# Frameworks  Grails, Struts
#
# Interests
#
# Platforms
#
# Server
#
# Experience
#
#
# Ellucian Higher Education System Pvt Ltd
#
# SOFTWARE DEVELOPER - PRODUCT: BANNER DOCUMENT MANAGEMENT
#
# •  Banner Document Management is one of the Ellucian’s core product intended to manage the documents by
#
# Tomcat 7 and 8, WebLogic 12c
#
# Linux, Windows
#
# Bengaluru, India
#
# Mar. 2017 - Till Date
#
# communicating with multiple application using web services. It serves as the best application to manage the huge data.
#
# in Tomcat and WebLogic 12c.
#
# the world. The project was under maintenance by applying db updates every quarter.
#
#
# •  Independently being responsible from designing, coding and unit test along with deployment on different environment
#
# •  Designed and developed BDM API enhancement of the application using groovy and grails within 5 months of period.
#
# •  Integrated Part of Sprint planning and Agile Scrum executions.
#
# •  Hands on git(Bitbucket) commands and applying distinct types of patches on production environment.
#
# •  Designed and implemented the complex logic on license pooling which is similar to Redis.
#
# CGI
#
# SOFTWARE ENGINEER - PRODUCT: AON RISK MAP APP
#
# •  An android project which is mainly in to insurance, calculating the statics of the risk involved in various part of
#
# •  Identified few defects and resolved. Was alone point of contact for an app.
#
# CGI
#
# SOFTWARE DEVELOPER - PRODUCT: CONCERT WEB APPLICATION FOR (AON)
#
# •  ConCert is a web–based application developed on top of a Main Frame application named IBIS to provide web based
#
# •  Handling escalated calls and providing Technical solution.
#
# •  Mentoring junior developers.
#
# •  preparation of Unit Test Plans (UTP).
#
# Education
#
# B.V.B College of Engineering and Technology - VTU(Visvesvaraya Technological
#
# University)
#
# solution for users to create policies and raise premium transactions.
#
# Bengaluru, India
#
# Bengaluru, India
#
# Jun. 2014 - Feb. 2017
#
# Nov. 2015 - Nov. 2016
#
# Hubballi, India
#
#
#
# B.E. IN COMPUTER SCIENCE AND ENGINEERING
#
# • CGPA : 7.81
#
# Basaveshwara Science College
#
# PRE UNIVERSITY
#
# • PUC - Percentage : 70
#
# BVVS
#
# SSLC
#
# • SSLC - Percentage : 82.53
#
# Honors & Awards
#
#
#
# Aug. 2009 - Jun. 2013
#
# Bagalkot, India
#
# End : Jun. 2009
#
# Bagalkot, India
#
# End : Mar. 2007
#
# Jan. 2016 Tap on the back, CGI employee recognition program
# Jul. 2017  YoungParticipant, Ellucian Hackathon event for building Alexa custom skill
#
#
#
# DEEPTI MULLUR · RÉSUMÉ
#
# Bangalore, India
#
# Bangalore, India
#
# 1

# %%
import nltk

# %%
nltk_tokens = nltk.word_tokenize(data)
print (nltk_tokens)
# Out:
# ['Contact', 'www.linkedin.com/in/ssamitkmr', '(', 'LinkedIn', ')', 'Top', 'Skills', 'Algorithms', 'Java', 'Python', 'Languages', 'English', '(', 'Professional', 'Working', ')', 'Hindi', '(', 'Native', 'or', 'Bilingual', ')', 'Honors-Awards', 'Certificate', 'of', 'Merit', 'Amit', 'Kumar', 'Actively', 'Looking', 'for', 'Opportunites|', 'Ex-Shuttl', '|', 'Ex-', 'Times', 'Internet', '|', 'IIT', 'Kanpur', 'Gurgaon', ',', 'India', 'Summary', 'Software', 'Developer', 'with', 'experience', 'of', 'building', 'scalable', 'tech', 'products', 'and', 'solutions', '.', 'Skilled', 'in', 'Python', ',', 'Nodejs', 'and', 'Java', '.', 'Strong', 'engineering', 'professional', 'with', 'a', 'Bachelor', '’', 's', 'Degree', 'from', 'IIT', 'Kanpur', '.', 'Experience', 'Udyami', 'Media', 'Labs', 'Co-Founder', 'July', '2019', '-', 'Present', 'Noida', 'Area', ',', 'India', 'Shuttl', 'Software', 'Engineer', 'September', '2018', '-', 'June', '2019', '(', '10', 'months', ')', 'Gurgaon', ',', 'India', 'Worked', 'in
# ...

# %%
type(data)
# Out:
# str

# %%
# !pip install pdfminer
# Out:
# ...
#      |████████████████████████████████| 4.2MB 1.4MB/s eta 0:00:01
# ...
#   Created wheel for pdfminer: filename=pdfminer-20191125-cp37-none-any.whl size=6140057 sha256=d8d1080400dc548d309e7cc80d6f20c2c5ad943af7db340bf92546e2c84eff6b
#   Stored in directory: /home/aman/.cache/pip/wheels/e1/00/af/720a55d74ba3615bb4709a3ded6dd71dc5370a586a0ff6f326
# Successfully built pdfminer
# ...

# %%
# !pdf2txt.py -o output.html "Dhananjaya Nayak - 5.9 Years - Axapta Dtd 9 Feb 2017.pdf"
