# %%
import pandas as pd

# %%
# !ls
# Out:
# 220_dataset.json	       links		paper_2.pdf  paper_6.pdf
# Amit.pdf		       ner.csv		paper_3.pdf  paper_7.pdf
# Colleges_and_Universities.csv  ner_dataset.csv	paper_4.pdf  Tuesday_work.ipynb
# convertcsv.csv		       paper_1.pdf	paper_5.pdf

# %%
from io import StringIO

from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from pdfminer.pdfpage import PDFPage


def convert_pdf_to_txt(path_to_file):
    rsrcmgr = PDFResourceManager()
    retstr = StringIO()
    codec = 'utf-8'
    laparams = LAParams()
    device = TextConverter(rsrcmgr, retstr, laparams=laparams)
    fp = open(path_to_file, 'rb')
    interpreter = PDFPageInterpreter(rsrcmgr, device)
    password = ""
    maxpages = 0
    caching = True
    pagenos=set()

    for page in PDFPage.get_pages(fp, pagenos, maxpages=maxpages, password=password,caching=caching, check_extractable=True):
        interpreter.process_page(page)

    text = retstr.getvalue()

    fp.close()
    device.close()
    retstr.close()
    return text

# %%
text = convert_pdf_to_txt("Amit.pdf")

# %%
print(text)
# Out:
# Contact
#
# www.linkedin.com/in/ssamitkmr
# (LinkedIn)
#
# Top Skills
# Algorithms
# Java
# Python
#
# Languages
# English (Professional Working)
# Hindi (Native or Bilingual)
#
# Honors-Awards
# Certificate of Merit
#
#
#
#
#
#
#
# Amit Kumar
#
# Actively Looking for Opportunites| Ex-Shuttl | Ex- Times Internet | IIT
# Kanpur
# Gurgaon, India
#
# Summary
# Software Developer with experience of building scalable tech
# products and solutions. Skilled in Python, Nodejs and Java. Strong
# engineering professional with a Bachelor’s Degree from IIT Kanpur.
#
# Experience
#
# Udyami Media Labs
# Co-Founder
# July 2019 - Present
# Noida Area, India
#
# Shuttl
# Software Engineer
# September 2018 - June 2019 (10 months)
# Gurgaon, India
# Worked in system-rewrite and software revamp of Shuttl from monolith
# architecture to microservice architecture.
#
# -  Developer Payments microservice with third-party integration such as Paytm,
# ...

# %%
contents = text

# %%
print(contents)
# Out:
# Contact
#
# www.linkedin.com/in/ssamitkmr
# (LinkedIn)
#
# Top Skills
# Algorithms
# Java
# Python
#
# Languages
# English (Professional Working)
# Hindi (Native or Bilingual)
#
# Honors-Awards
# Certificate of Merit
#
#
#
#
#
#
#
# Amit Kumar
#
# Actively Looking for Opportunites| Ex-Shuttl | Ex- Times Internet | IIT
# Kanpur
# Gurgaon, India
#
# Summary
# Software Developer with experience of building scalable tech
# products and solutions. Skilled in Python, Nodejs and Java. Strong
# engineering professional with a Bachelor’s Degree from IIT Kanpur.
#
# Experience
#
# Udyami Media Labs
# Co-Founder
# July 2019 - Present
# Noida Area, India
#
# Shuttl
# Software Engineer
# September 2018 - June 2019 (10 months)
# Gurgaon, India
# Worked in system-rewrite and software revamp of Shuttl from monolith
# architecture to microservice architecture.
#
# -  Developer Payments microservice with third-party integration such as Paytm,
# ...

# %%
file2write=open("abc.txt",'w')
file2write.write(contents)
file2write.close()

# %%
with open ('abc.txt', 'rt') as myfile:  # Open file lorem.txt for reading text
    for myline in myfile:                 # For each line, read it to a string 
        print(myline)
# Out:
# Contact
#
#
#
# www.linkedin.com/in/ssamitkmr
#
# (LinkedIn)
#
#
#
# Top Skills
#
# Algorithms
#
# Java
#
# Python
#
#
#
# Languages
#
# English (Professional Working)
#
# Hindi (Native or Bilingual)
#
#
#
# Honors-Awards
#
# Certificate of Merit
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Amit Kumar
#
#
#
# Actively Looking for Opportunites| Ex-Shuttl | Ex- Times Internet | IIT
#
# Kanpur
#
# Gurgaon, India
#
#
#
# Summary
#
# Software Developer with experience of building scalable tech
#
# products and solutions. Skilled in Python, Nodejs and Java. Strong
#
# engineering professional with a Bachelor’s Degree from IIT Kanpur.
#
#
#
# Experience
#
#
#
# Udyami Media Labs
#
# Co-Founder
#
# July 2019 - Present
#
# Noida Area, India
#
#
#
# Shuttl
#
# Software Engineer
#
# September 2018 - June 2019 (10 months)
#
# Gurgaon, India
#
# Worked in system-rewrite and software revamp of Shuttl from monolith
#
# architecture to microservice architecture.
#
#
#
# ...

# %%
mylines = []                             # Declare an empty list named mylines.
with open ('abc.txt', 'rt') as myfile: # Open lorem.txt for reading text data.
    for myline in myfile:                # For each line, stored as myline,
        mylines.append(myline)           # add its contents to mylines.
print(mylines)
# Out:
# ['Contact\n', '\n', 'www.linkedin.com/in/ssamitkmr\n', '(LinkedIn)\n', '\n', 'Top Skills\n', 'Algorithms\n', 'Java\n', 'Python\n', '\n', 'Languages\n', 'English (Professional Working)\n', 'Hindi (Native or Bilingual)\n', '\n', 'Honors-Awards\n', 'Certificate of Merit\n', '\n', '\xa0\n', '\n', '\xa0\n', '\n', '\xa0\n', '\n', 'Amit Kumar\n', '\n', 'Actively Looking for Opportunites| Ex-Shuttl | Ex- Times Internet | IIT\n', 'Kanpur\n', 'Gurgaon, India\n', '\n', 'Summary\n', 'Software Developer with experience of building scalable tech\n', 'products and solutions. Skilled in Python, Nodejs and Java. Strong\n', 'engineering professional with a Bachelor’s Degree from IIT Kanpur. \n', '\n', 'Experience\n', '\n', 'Udyami Media Labs\n', 'Co-Founder\n', 'July 2019\xa0-\xa0Present\xa0\n', 'Noida Area, India\n', '\n', 'Shuttl\n', 'Software Engineer\n', 'September 2018\xa0-\xa0June 2019\xa0(10 months)\n', 'Gurgaon, India\n', 'Worked in system-rewrite and software revamp of Shuttl from monolith\n'
# ...

# %%
tokens = [t for t in text.split()]
 
print (tokens)
# Out:
# ['Contact', 'www.linkedin.com/in/ssamitkmr', '(LinkedIn)', 'Top', 'Skills', 'Algorithms', 'Java', 'Python', 'Languages', 'English', '(Professional', 'Working)', 'Hindi', '(Native', 'or', 'Bilingual)', 'Honors-Awards', 'Certificate', 'of', 'Merit', 'Amit', 'Kumar', 'Actively', 'Looking', 'for', 'Opportunites|', 'Ex-Shuttl', '|', 'Ex-', 'Times', 'Internet', '|', 'IIT', 'Kanpur', 'Gurgaon,', 'India', 'Summary', 'Software', 'Developer', 'with', 'experience', 'of', 'building', 'scalable', 'tech', 'products', 'and', 'solutions.', 'Skilled', 'in', 'Python,', 'Nodejs', 'and', 'Java.', 'Strong', 'engineering', 'professional', 'with', 'a', 'Bachelor’s', 'Degree', 'from', 'IIT', 'Kanpur.', 'Experience', 'Udyami', 'Media', 'Labs', 'Co-Founder', 'July', '2019', '-', 'Present', 'Noida', 'Area,', 'India', 'Shuttl', 'Software', 'Engineer', 'September', '2018', '-', 'June', '2019', '(10', 'months)', 'Gurgaon,', 'India', 'Worked', 'in', 'system-rewrite', 'and', 'software', 'revamp', 'of', 'Shuttl', 'f
# ...

# %%
import nltk

# %%
freq = nltk.FreqDist(tokens)
 
for key,val in freq.items():
 
    print (str(key) + ':' + str(val))
# Out:
# Contact:1
# www.linkedin.com/in/ssamitkmr:1
# (LinkedIn):1
# Top:1
# Skills:1
# Algorithms:1
# Java:1
# Python:2
# Languages:1
# English:1
# (Professional:1
# Working):1
# Hindi:1
# (Native:1
# or:1
# Bilingual):1
# Honors-Awards:1
# Certificate:1
# of:12
# Merit:1
# Amit:1
# Kumar:1
# Actively:1
# Looking:1
# for:13
# Opportunites|:1
# Ex-Shuttl:1
# |:2
# Ex-:1
# Times:3
# Internet:3
# IIT:2
# Kanpur:2
# Gurgaon,:3
# India:5
# Summary:1
# Software:4
# Developer:4
# with:6
# experience:1
# building:1
# scalable:1
# tech:1
# products:2
# and:11
# solutions.:1
# Skilled:1
# in:5
# Python,:1
# Nodejs:2
# Java.:1
# Strong:1
# engineering:1
# professional:1
# a:4
# Bachelor’s:1
# Degree:1
# from:4
# Kanpur.:1
# Experience:1
# Udyami:1
# Media:1
# Labs:1
# Co-Founder:1
# July:3
# 2019:2
# -:11
# Present:1
# Noida:2
# Area,:2
# Shuttl:3
# Engineer:2
# September:1
# 2018:2
# June:1
# (10:1
# months):4
# Worked:3
# system-rewrite:1
# software:1
# revamp:1
# monolith:1
# architecture:1
# to:8
# ...

# %%
freq.plot(20, cumulative=False)

# %%
from nltk.corpus import stopwords
 
stopwords.words('english')
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
# ...

# %%
clean_tokens = tokens[:]
 
sr = stopwords.words('english')
 
for token in tokens:
 
    if token in stopwords.words('english'):
 
        clean_tokens.remove(token)

# %%
print(clean_tokens)
# Out:
# ['Contact', 'www.linkedin.com/in/ssamitkmr', '(LinkedIn)', 'Top', 'Skills', 'Algorithms', 'Java', 'Python', 'Languages', 'English', '(Professional', 'Working)', 'Hindi', '(Native', 'Bilingual)', 'Honors-Awards', 'Certificate', 'Merit', 'Amit', 'Kumar', 'Actively', 'Looking', 'Opportunites|', 'Ex-Shuttl', '|', 'Ex-', 'Times', 'Internet', '|', 'IIT', 'Kanpur', 'Gurgaon,', 'India', 'Summary', 'Software', 'Developer', 'experience', 'building', 'scalable', 'tech', 'products', 'solutions.', 'Skilled', 'Python,', 'Nodejs', 'Java.', 'Strong', 'engineering', 'professional', 'Bachelor’s', 'Degree', 'IIT', 'Kanpur.', 'Experience', 'Udyami', 'Media', 'Labs', 'Co-Founder', 'July', '2019', '-', 'Present', 'Noida', 'Area,', 'India', 'Shuttl', 'Software', 'Engineer', 'September', '2018', '-', 'June', '2019', '(10', 'months)', 'Gurgaon,', 'India', 'Worked', 'system-rewrite', 'software', 'revamp', 'Shuttl', 'monolith', 'architecture', 'microservice', 'architecture.', '-', 'Developer', 'Payments', 'mic
# ...

# %%
freq = nltk.FreqDist(clean_tokens)
 
for key,val in freq.items():
 
    print (str(key) + ':' + str(val))
# Out:
# Contact:1
# www.linkedin.com/in/ssamitkmr:1
# (LinkedIn):1
# Top:1
# Skills:1
# Algorithms:1
# Java:1
# Python:2
# Languages:1
# English:1
# (Professional:1
# Working):1
# Hindi:1
# (Native:1
# Bilingual):1
# Honors-Awards:1
# Certificate:1
# Merit:1
# Amit:1
# Kumar:1
# Actively:1
# Looking:1
# Opportunites|:1
# Ex-Shuttl:1
# |:2
# Ex-:1
# Times:3
# Internet:3
# IIT:2
# Kanpur:2
# Gurgaon,:3
# India:5
# Summary:1
# Software:4
# Developer:4
# experience:1
# building:1
# scalable:1
# tech:1
# products:2
# solutions.:1
# Skilled:1
# Python,:1
# Nodejs:2
# Java.:1
# Strong:1
# engineering:1
# professional:1
# Bachelor’s:1
# Degree:1
# Kanpur.:1
# Experience:1
# Udyami:1
# Media:1
# Labs:1
# Co-Founder:1
# July:3
# 2019:2
# -:11
# Present:1
# Noida:2
# Area,:2
# Shuttl:3
# Engineer:2
# September:1
# 2018:2
# June:1
# (10:1
# months):4
# Worked:3
# system-rewrite:1
# software:1
# revamp:1
# monolith:1
# architecture:1
# microservice:3
# architecture.:1
# Payments:1
# third-party:1
# ...

# %%
from nltk.tokenize import sent_tokenize
print(sent_tokenize(text))
# Out:
# ['Contact\n\nwww.linkedin.com/in/ssamitkmr\n(LinkedIn)\n\nTop Skills\nAlgorithms\nJava\nPython\n\nLanguages\nEnglish (Professional Working)\nHindi (Native or Bilingual)\n\nHonors-Awards\nCertificate of Merit\n\n\xa0\n\n\xa0\n\n\xa0\n\nAmit Kumar\n\nActively Looking for Opportunites| Ex-Shuttl | Ex- Times Internet | IIT\nKanpur\nGurgaon, India\n\nSummary\nSoftware Developer with experience of building scalable tech\nproducts and solutions.', 'Skilled in Python, Nodejs and Java.', 'Strong\nengineering professional with a Bachelor’s Degree from IIT Kanpur.', 'Experience\n\nUdyami Media Labs\nCo-Founder\nJuly 2019\xa0-\xa0Present\xa0\nNoida Area, India\n\nShuttl\nSoftware Engineer\nSeptember 2018\xa0-\xa0June 2019\xa0(10 months)\nGurgaon, India\nWorked in system-rewrite and software revamp of Shuttl from monolith\narchitecture to microservice architecture.', '-  Developer Payments microservice with third-party integration such as Paytm,\nMobikwik, Razorpay, etc.', '(Flask, Postgres, Rabb
# ...

# %%
from nltk.stem import PorterStemmer
 
stemmer = PorterStemmer()
 
print(stemmer.stem(text))
# Out:
# contact
#
# www.linkedin.com/in/ssamitkmr
# (linkedin)
#
# top skills
# algorithms
# java
# python
#
# languages
# english (professional working)
# hindi (native or bilingual)
#
# honors-awards
# certificate of merit
#
#
#
#
#
#
#
# amit kumar
#
# actively looking for opportunites| ex-shuttl | ex- times internet | iit
# kanpur
# gurgaon, india
#
# summary
# software developer with experience of building scalable tech
# products and solutions. skilled in python, nodejs and java. strong
# engineering professional with a bachelor’s degree from iit kanpur.
#
# experience
#
# udyami media labs
# co-founder
# july 2019 - present
# noida area, india
#
# shuttl
# software engineer
# september 2018 - june 2019 (10 months)
# gurgaon, india
# worked in system-rewrite and software revamp of shuttl from monolith
# architecture to microservice architecture.
#
# -  developer payments microservice with third-party integration such as paytm,
# ...

# %%
from nltk import word_tokenize, pos_tag
print(len(text))
'''for i in range(0,len(text)):
    token_comment = word_tokenize(text[i])
    tagged_comment = pos_tag(token_comment)
    print( [(word, tag) for word, tag in tagged_comment if (tag=='NNP')])
    '''

print(text)
# Out:
# 3139
# Contact
#
# www.linkedin.com/in/ssamitkmr
# (LinkedIn)
#
# Top Skills
# Algorithms
# Java
# Python
#
# Languages
# English (Professional Working)
# Hindi (Native or Bilingual)
#
# Honors-Awards
# Certificate of Merit
#
#
#
#
#
#
#
# Amit Kumar
#
# Actively Looking for Opportunites| Ex-Shuttl | Ex- Times Internet | IIT
# Kanpur
# Gurgaon, India
#
# Summary
# Software Developer with experience of building scalable tech
# products and solutions. Skilled in Python, Nodejs and Java. Strong
# engineering professional with a Bachelor’s Degree from IIT Kanpur.
#
# Experience
#
# Udyami Media Labs
# Co-Founder
# July 2019 - Present
# Noida Area, India
#
# Shuttl
# Software Engineer
# September 2018 - June 2019 (10 months)
# Gurgaon, India
# Worked in system-rewrite and software revamp of Shuttl from monolith
# architecture to microservice architecture.
#
# -  Developer Payments microservice with third-party integration such as Paytm,
# ...

# %%
from nltk.tokenize import word_tokenize
tokenizer = word_tokenize(text)

# %%
print(tokenizer)
# Out:
# ['Contact', 'www.linkedin.com/in/ssamitkmr', '(', 'LinkedIn', ')', 'Top', 'Skills', 'Algorithms', 'Java', 'Python', 'Languages', 'English', '(', 'Professional', 'Working', ')', 'Hindi', '(', 'Native', 'or', 'Bilingual', ')', 'Honors-Awards', 'Certificate', 'of', 'Merit', 'Amit', 'Kumar', 'Actively', 'Looking', 'for', 'Opportunites|', 'Ex-Shuttl', '|', 'Ex-', 'Times', 'Internet', '|', 'IIT', 'Kanpur', 'Gurgaon', ',', 'India', 'Summary', 'Software', 'Developer', 'with', 'experience', 'of', 'building', 'scalable', 'tech', 'products', 'and', 'solutions', '.', 'Skilled', 'in', 'Python', ',', 'Nodejs', 'and', 'Java', '.', 'Strong', 'engineering', 'professional', 'with', 'a', 'Bachelor', '’', 's', 'Degree', 'from', 'IIT', 'Kanpur', '.', 'Experience', 'Udyami', 'Media', 'Labs', 'Co-Founder', 'July', '2019', '-', 'Present', 'Noida', 'Area', ',', 'India', 'Shuttl', 'Software', 'Engineer', 'September', '2018', '-', 'June', '2019', '(', '10', 'months', ')', 'Gurgaon', ',', 'India', 'Worked', 'in
# ...

# %%
from nltk import pos_tag

# %%
tagged_words = pos_tag(tokenizer)

# %%
print(tagged_words)
# Out:
# [('Contact', 'NNP'), ('www.linkedin.com/in/ssamitkmr', 'NN'), ('(', '('), ('LinkedIn', 'NNP'), (')', ')'), ('Top', 'NNP'), ('Skills', 'NNP'), ('Algorithms', 'NNP'), ('Java', 'NNP'), ('Python', 'NNP'), ('Languages', 'NNP'), ('English', 'NNP'), ('(', '('), ('Professional', 'NNP'), ('Working', 'NNP'), (')', ')'), ('Hindi', 'NNP'), ('(', '('), ('Native', 'NNP'), ('or', 'CC'), ('Bilingual', 'NNP'), (')', ')'), ('Honors-Awards', 'NNP'), ('Certificate', 'NNP'), ('of', 'IN'), ('Merit', 'NNP'), ('Amit', 'NNP'), ('Kumar', 'NNP'), ('Actively', 'RB'), ('Looking', 'VBG'), ('for', 'IN'), ('Opportunites|', 'NNP'), ('Ex-Shuttl', 'NNP'), ('|', 'NNP'), ('Ex-', 'NNP'), ('Times', 'NNP'), ('Internet', 'NNP'), ('|', 'NNP'), ('IIT', 'NNP'), ('Kanpur', 'NNP'), ('Gurgaon', 'NNP'), (',', ','), ('India', 'NNP'), ('Summary', 'NNP'), ('Software', 'NNP'), ('Developer', 'NNP'), ('with', 'IN'), ('experience', 'NN'), ('of', 'IN'), ('building', 'NN'), ('scalable', 'JJ'), ('tech', 'NN'), ('products', 'NNS'), ('and', '
# ...

# %%
print( [(word, tag) for word, tag in tagged_words if (tag=='NNP')])
# Out:
# [('Contact', 'NNP'), ('LinkedIn', 'NNP'), ('Top', 'NNP'), ('Skills', 'NNP'), ('Algorithms', 'NNP'), ('Java', 'NNP'), ('Python', 'NNP'), ('Languages', 'NNP'), ('English', 'NNP'), ('Professional', 'NNP'), ('Working', 'NNP'), ('Hindi', 'NNP'), ('Native', 'NNP'), ('Bilingual', 'NNP'), ('Honors-Awards', 'NNP'), ('Certificate', 'NNP'), ('Merit', 'NNP'), ('Amit', 'NNP'), ('Kumar', 'NNP'), ('Opportunites|', 'NNP'), ('Ex-Shuttl', 'NNP'), ('|', 'NNP'), ('Ex-', 'NNP'), ('Times', 'NNP'), ('Internet', 'NNP'), ('|', 'NNP'), ('IIT', 'NNP'), ('Kanpur', 'NNP'), ('Gurgaon', 'NNP'), ('India', 'NNP'), ('Summary', 'NNP'), ('Software', 'NNP'), ('Developer', 'NNP'), ('Python', 'NNP'), ('Nodejs', 'NNP'), ('Java', 'NNP'), ('Strong', 'NNP'), ('Bachelor', 'NNP'), ('’', 'NNP'), ('Degree', 'NNP'), ('IIT', 'NNP'), ('Kanpur', 'NNP'), ('Experience', 'NNP'), ('Udyami', 'NNP'), ('Media', 'NNP'), ('Labs', 'NNP'), ('Co-Founder', 'NNP'), ('July', 'NNP'), ('Noida', 'NNP'), ('Area', 'NNP'), ('India', 'NNP'), ('Shuttl', 'N
# ...
